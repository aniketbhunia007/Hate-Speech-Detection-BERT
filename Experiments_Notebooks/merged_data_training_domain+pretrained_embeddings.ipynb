# %% [markdown]
# There is a change in preprocessing in this notebook, we removed all the numbers from tweets, which helped in training more robust word2vec embeddings

# %% [markdown]
# Analysis on scraped dataset

# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np

# %%
import pickle
import sys
import nltk
from nltk.stem.porter import *

from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cf_data_1 = pd.read_csv('/content/drive/My Drive/Hate_Speech_Detection_git/data_1/hatespeech_NAACL_SRW.csv',encoding = "ISO-8859-1")
cf_data_2 = pd.read_csv('/content/drive/My Drive/Hate_Speech_Detection_git/data_1/hatespeech_NLP+CSS.csv')

cf_data_3 = pd.read_csv('/content/drive/My Drive/Hate_Speech_Detection_git/data_2/labeled_data.csv',encoding = "ISO-8859-1")
## this is the scraped data

cf_data_3.rename({'Unnamed: 0':'ID','tweet':'Tweets'},axis=1,inplace=True)

labels_1 = pd.read_csv('/content/drive/My Drive/Hate_Speech_Detection_git/data_1/NAACL_SRW_2016.csv',header=None,names=['ID','class'])
labels_2 = pd.read_csv('/content/drive/My Drive/Hate_Speech_Detection_git/data_1/NLP+CSS_2016.csv',sep='\s')

labels_2.rename({'TweetID':'ID','Expert':'class'},axis=1,inplace=True)

cf_data_1.rename({'Unnamed: 0':'index_col'},axis=1,inplace=True)
cf_data_2.rename({'Unnamed: 0':'index_col'},axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# #### Merging the cf_data_1 with its labelss

# %% [markdown]
# ### Function for merging

# %%
def label_merging(data, labels):
    labels['ID'] = labels['ID'].astype(int)
    print(labels['ID'].nunique())
    print('Null IDs in data 1 = ' ,data['ID'].isna().sum())
    
    data['ID'].fillna(0,inplace=True)
    data['ID'] = data['ID'].astype(int)
    
    print('data shape ='  ,data.shape)
    print('IDs common in data and labels =',sum(data['ID'].isin(labels['ID'])))
    
    train = data.merge(labels, on='ID',how='inner')#['class'].isna().sum()
    return train

# %%
train_1 = label_merging(cf_data_1,labels_1)
# Out:
# 16849
# Null IDs in data 1 =  2
# data shape = (16037, 11)
# IDs common in data and labels = 11238

# %%
train_2 = label_merging(cf_data_2, labels_2)
# Out:
# 6909
# Null IDs in data 1 =  0
# data shape = (6271, 11)
# IDs common in data and labels = 6271

# %%
train_3 = cf_data_3.copy()

# %%
train_1['class'].value_counts()
# Out:
# none      7733
# sexism    2258
# racism    1319
# Name: class, dtype: int64

# %%
train_2['class'].value_counts()
# Out:
# neither    5526
# sexism      639
# racism       80
# both         26
# Name: class, dtype: int64

# %%
train_3['class'].value_counts()
# Out:
# 1    19190
# 2     4163
# 0     1430
# Name: class, dtype: int64

# %%
t1 = train_1[['ID','Tweets','class']]
t2 = train_2[['ID','Tweets','class']]
t3 = train_3[['ID','Tweets','class']]
merged = pd.concat([t1,t2,t3],axis=0).reset_index(drop=True)

# %% [markdown]
# ### Target Analysis

# %%
merged['class'].value_counts()
# Out:
# 1          19190
# none        7733
# neither     5526
# 2           4163
# sexism      2897
# 0           1430
# racism      1399
# both          26
# Name: class, dtype: int64

# %% [markdown]
# ### Very basic exploration

# %%
train = merged.copy()

# %%
train.rename(columns={'Tweets':'tweet'},inplace=True)

# %%
train['tweet'] = train['tweet'].astype(str)

# %%
## word and char count, avg_word length and all
train['word_count'] = train['tweet'].apply(lambda x: len(str(x).split(" ")))
train[['tweet','word_count']].head()
# Out:
#                                                tweet  word_count
# 0  @ummayman90 Again, your entire concept of god ...          20
# 1  @anjemchoudary Your prophet was a rapist, murd...          21
# 2  RT @DilanaKurdi: Yazidi children who are taken...          17
# 3  These girls are the equivalent of the irritati...          18
# 4  @lauracdean I love how the Islamofascists recr...          24

# %%
train['char_count'] = train['tweet'].str.len() ## this also includes spaces
train[['tweet','char_count']].head()
# Out:
#                                                tweet  char_count
# 0  @ummayman90 Again, your entire concept of god ...         133
# 1  @anjemchoudary Your prophet was a rapist, murd...         140
# 2  RT @DilanaKurdi: Yazidi children who are taken...         135
# 3  These girls are the equivalent of the irritati...          99
# 4  @lauracdean I love how the Islamofascists recr...         133

# %%
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))

train['avg_word'] = train['tweet'].apply(lambda x: avg_word(x))
train[['tweet','avg_word']].head()
# Out:
#                                                tweet  avg_word
# 0  @ummayman90 Again, your entire concept of god ...  5.700000
# 1  @anjemchoudary Your prophet was a rapist, murd...  5.714286
# 2  RT @DilanaKurdi: Yazidi children who are taken...  7.000000
# 3  These girls are the equivalent of the irritati...  4.555556
# 4  @lauracdean I love how the Islamofascists recr...  4.583333

# %% [markdown]
# #### Hashtags

# %%
train['hastags'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['tweet','hastags']].head()
# Out:
#                                                tweet  hastags
# 0  @ummayman90 Again, your entire concept of god ...        1
# 1  @anjemchoudary Your prophet was a rapist, murd...        0
# 2  RT @DilanaKurdi: Yazidi children who are taken...        2
# 3  These girls are the equivalent of the irritati...        1
# 4  @lauracdean I love how the Islamofascists recr...        0

# %% [markdown]
# ### Basic Preprocessing

# %% [markdown]
# Every word followed by @ is some twitter ID of an user, which shouldn't be considered in our analysis, so lets do the stemming, where we remove @ alonwith the word followed by it

# %% [markdown]
# #### Removing user IDs from text

# %%
train['tweet'] = train['tweet'].apply(lambda x:' '.join(i for i in [a for a in x.split() if a.find('@')==-1]))

# %% [markdown]
# Removing all the links from tweets

# %%
train['tweet'] = train['tweet'].apply(lambda x:' '.join(i for i in [a for a in x.split() if a.find('http')==-1]))

# %% [markdown]
# Removing numbers

# %%
train['tweet'] = train['tweet'].apply(lambda x:''.join([i for i in x if not i.isdigit()]))

# %% [markdown]
# #### Converting to Lower case

# %%
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['tweet'].head()
# Out:
# 0    again, your entire concept of god corresponds ...
# 1    your prophet was a rapist, murderer, pedophile...
# 2    rt yazidi children who are taken from their pa...
# 3    these girls are the equivalent of the irritati...
# 4    i love how the islamofascists recruit and year...
# Name: tweet, dtype: object

# %% [markdown]
# There is no use of punctuation mostly, so removing it

# %%
train['tweet'] = train['tweet'].str.replace('[^\w\s]','')
train['tweet'].head()
# Out:
# 0    again your entire concept of god corresponds t...
# 1    your prophet was a rapist murderer pedophile c...
# 2    rt yazidi children who are taken from their pa...
# 3    these girls are the equivalent of the irritati...
# 4    i love how the islamofascists recruit and year...
# Name: tweet, dtype: object

# %% [markdown]
# #### Removing stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['tweet'].head()
# Out:
# 0    entire concept god corresponds tyrannical eart...
# 1    prophet rapist murderer pedophile caravan robb...
# 2    rt yazidi children taken parents forcibly conv...
# 3    girls equivalent irritating asian girls couple...
# 4    love islamofascists recruit year old jihadis t...
# Name: tweet, dtype: object

# %% [markdown]
# #### Most common and rare words

# %%
freq = pd.Series(' '.join(train['tweet']).split()).value_counts()#[:10]
freq
# Out:
# rt             10506
# bitch           8317
# like            3815
# mkr             3788
# im              3631
#                ...
# readlisten         1
# ar                 1
# succession         1
# xans               1
# holipalooza        1
# Length: 30398, dtype: int64

# %% [markdown]
# rt is a very frequent word occuring almost in every tweet, and it doesnt hold any meaning so lets just remove it, I guess it there are such more words but those are all seem to be hatespeech. So we will just keep hate speechwords from above list, lets remove the rest

# %%
remove_word = ['rt','mkr','im']

# %%
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in remove_word))
train['tweet'].head()
# Out:
# 0    entire concept god corresponds tyrannical eart...
# 1    prophet rapist murderer pedophile caravan robb...
# 2    yazidi children taken parents forcibly convert...
# 3    girls equivalent irritating asian girls couple...
# 4    love islamofascists recruit year old jihadis t...
# Name: tweet, dtype: object

# %%
freq.shape
# Out:
# (30398,)

# %% [markdown]
# Doesnt really make sense to remove rare words, i.e. the words with count 1. Because we might lose hateful words this way

# %%
from textblob import TextBlob
nltk.download('punkt')
TextBlob(train['tweet'][1]).words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WordList(['prophet', 'rapist', 'murderer', 'pedophile', 'caravan', 'robber', 'slave', 'trader', 'bigot', 'sexist', 'god', 'would', 'never', 'use', 'scum'])

# %% [markdown]
# #### Lemmetization
# smart stemming

# %%
from textblob import Word
nltk.download('wordnet')
train['tweet'] = train['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
train['tweet'].head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    entire concept god corresponds tyrannical eart...
# 1    prophet rapist murderer pedophile caravan robb...
# 2    yazidi child taken parent forcibly converted i...
# 3    girl equivalent irritating asian girl couple y...
# 4    love islamofascists recruit year old jihadis t...
# Name: tweet, dtype: object

# %% [markdown]
# ##### So now it seems that the data is almost clean! Lets explore advanced preprocessing/ text representation techniques

# %% [markdown]
# ### Target creation

# %%
train['class'].unique()#.isna().sum()
# Out:
# array(['racism', 'none', 'sexism', 'neither', 'both', 2, 1, 0],
#       dtype=object)

# %%
train['class'].replace(['racism', 'sexism',0, 1, 'both', 'none', 'neither',2],['hate','hate','hate','hate','hate','null','null','null'],inplace=True)
train['class'].value_counts()
# Out:
# hate    24942
# null    17422
# Name: class, dtype: int64

# %%
train['class'].replace(['null','hate'],[0,1],inplace=True)

# %% [markdown]
# ### N-Grams

# %%
TextBlob(train['tweet'][0]).ngrams(2)
# Out:
# [WordList(['entire', 'concept']),
#  WordList(['concept', 'god']),
#  WordList(['god', 'corresponds']),
#  WordList(['corresponds', 'tyrannical']),
#  WordList(['tyrannical', 'earthly']),
#  WordList(['earthly', 'egomaniac']),
#  WordList(['egomaniac', 'simple']),
#  WordList(['simple', 'stupid']),
#  WordList(['stupid', 'islam'])]

# %% [markdown]
# ### Removing Duplicates

# %%
train = train.drop_duplicates(subset='ID')

# %% [markdown]
# ### Basic Model on whole dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_valid,y_t,y_v = train_test_split(train['tweet'],train['class'],test_size=0.2,random_state=234)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=100, lowercase=True, analyzer='word',
 stop_words= 'english',ngram_range=(1,1))

tfidf.fit(train['tweet'])

x_t = tfidf.transform(x_train)
x_v = tfidf.transform(x_valid)

# %%
def model_training(clf, x_t, y_t, x_v=None , y_v=None ,task='binary:logistic'):
    clf.fit(x_t,y_t)
    print('training accuracy', clf.score(x_t,y_t))
    
    if task=='binary:logistic':
      print('validation accuracy', clf.score(x_v,y_v))
      print('validation f1_score',f1_score(clf.predict(x_v),y_v))
      print('validation roc_auc score',roc_auc_score(y_v,clf.predict_proba(x_v)[::,-1]))
      print('confusion matrix \n',confusion_matrix(y_v, clf.predict(x_v)))
    
    if task=='reg:linear':
      print('validation r2_score', clf.score(x_v,y_v))
      print('validation MSE',mean_squared_error(clf.predict(x_v),y_v))

            
    return clf

# %%
# y_t.value_counts()

13966/19925
# Out:
# 0.7009284818067754

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, classification_report, roc_auc_score, confusion_matrix, accuracy_score
from xgboost import XGBClassifier

lgr =  LogisticRegression(n_jobs=1)
xgb = XGBClassifier(n_estimators=500, max_depth=5,learning_rate=0.1,scale_pos_weight=1.4266790777602751)

model_training(xgb,x_t,y_t,x_v,y_v)
# model_training(lgr,x_t,y_t,x_v,y_v)
# Out:
# training accuracy 0.857264903176813
# validation accuracy 0.8553530751708428
# validation f1_score 0.8783654357773757
# validation roc_auc score 0.9169276701896655
# confusion matrix
#  [[2632  265]
#  [ 878 4127]]
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=1, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# ## XGB results
# training accuracy 0.8751740286039742
# validation accuracy 0.8567451278157429
# validation f1_score 0.8815403934700711
# validation roc_auc score 0.9185450724629186
# confusion matrix 
#  [[2558  339]
#  [ 793 4212]]

# LR Results
#training accuracy 0.857264903176813
# validation accuracy 0.8553530751708428
# validation f1_score 0.8783654357773757
# validation roc_auc score 0.9169276701896655
# confusion matrix 
#  [[2632  265]
#  [ 878 4127]]

# %%
y_v.value_counts()
# Out:
# 1    5005
# 0    2897
# Name: class, dtype: int64

# %%
#### We are getting good results over here, lets just also check whether the predictions using ranks would work here or not. 
#### I guess it wont work as here 1s are in majority, so rare chances of any improvement

# %%
y_v.mean()
# Out:
# 0.6333839534295115

# %%
# probabs_df = pd.DataFrame(y_v)
# probabs_df['original_index'] = y_v.index
# probabs_df['probab'] = lgr.predict_proba(x_v)[::,-1]
# probabs_df['preds'] = (lgr.predict_proba(x_v)[::,-1]>0.5).astype(int)

probabs_df = pd.DataFrame(y_v)
probabs_df['original_index'] = y_v.index
# probabs_df['probab'] = lgr.predict_proba(x_v)[::,-1]
probabs_df['probab'] = xgb.predict_proba(x_v)[::,-1]


probabs_df = probabs_df.sort_values(by = 'probab',ascending=False).reset_index(drop=True)

probabs_df.loc[0:int(x_v.todense().shape[0]*y_v.mean()),'preds'] = 1

probabs_df.loc[int(x_v.todense().shape[0]*y_v.mean()):,'preds'] = 0

np.mean(probabs_df['class']==probabs_df['preds'])

### True Positives increased but as said, it costed us the overall accuracy,
### even the F1 score isnt increased this, which had imprved in NLP+CSS model
# Out:
# 0.8364215744128408

# %%
confusion_matrix(probabs_df['class'],probabs_df['preds'])
# Out:
# array([[2763,  693],
#        [ 693, 4324]])

# %%
f1_score(probabs_df['class'],probabs_df['preds'])
# Out:
# 0.8618696432130756

# %%
bad_preds = x_valid.loc[probabs_df[probabs_df['class']!=probabs_df['preds']]['original_index'].values]

# %%
original_class = probabs_df[probabs_df['class']!=probabs_df['preds']][['class','original_index']]
pred_class = probabs_df[probabs_df['class']!=probabs_df['preds']][['preds','probab']]

# %% [markdown]
# ### Some serious mindf*ck here

# %%
train.loc[39516]
# Out:
# ID                                22402
# tweet         bitch buy sparkling water
# class                                 0
# word_count                            6
# char_count                           45
# avg_word                        6.66667
# hastags                               0
# Name: 39516, dtype: object

# %%
pd.concat([bad_preds.reset_index(drop=True),original_class.reset_index(drop=True),pred_class.reset_index(drop=True)],axis=1)

# %% [markdown]
# ### Word Embeddings Training

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def read_input(data):
    """This method reads the input file which is in gzip format"""
    i=0
    for line in data['tweet']: 
      i+=1
      if (i%10000==0):
        logging.info ("read {0} tweets".format(i))
      # do some pre-processing and return a list of words for each tweet, basically doing tokenizing
      yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list(read_input(train))
logging.info ("Done reading data file")
# Out:
# 2019-11-09 22:29:54,810 : INFO : read 10000 tweets
# 2019-11-09 22:29:54,900 : INFO : read 20000 tweets
# 2019-11-09 22:29:54,985 : INFO : read 30000 tweets
# 2019-11-09 22:29:55,084 : INFO : Done reading data file

# %%
documents = []
i=0
for line in train['tweet']: 
    i+=1
    if (i%10000==0):
      logging.info ("read {0} tweets".format(i))
      # do some pre-processing and return a list of words for each tweet, basically doing tokenizing
    # documents.append(gensim.utils.simple_preprocess(line))
    documents.append(nltk.word_tokenize(line))
# Out:
# 2019-11-09 22:29:57,197 : INFO : read 10000 tweets
# 2019-11-09 22:29:57,995 : INFO : read 20000 tweets
# 2019-11-09 22:29:58,810 : INFO : read 30000 tweets

# %%
len(documents)
# Out:
# 39506

# %%
# %%time

model = gensim.models.Word2Vec(documents, size=50, min_count=2, workers=5)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2019-11-09 22:30:00,214 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-11-09 22:30:00,216 : INFO : collecting all words and their counts
# 2019-11-09 22:30:00,218 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-09 22:30:00,240 : INFO : PROGRESS: at sentence #10000, processed 73710 words, keeping 11173 word types
# 2019-11-09 22:30:00,258 : INFO : PROGRESS: at sentence #20000, processed 147079 words, keeping 18444 word types
# 2019-11-09 22:30:00,277 : INFO : PROGRESS: at sentence #30000, processed 224191 words, keeping 23575 word types
# 2019-11-09 22:30:00,296 : INFO : collected 27600 word types from a corpus of 297884 raw words and 39506 sentences
# 2019-11-09 22:30:00,296 : INFO : Loading a fresh vocabulary
# 2019-11-09 22:30:00,324 : INFO : effective_min_count=2 retains 12387 unique words (44% of original 27600, drops 15213)
# 2019-11-09 22:30:00,324 : INFO : effective_min_count=2 leaves 282671 word corpus (94% of original 297884, drops 15213)
# 2019-11-09 22:30:00,358 : INFO : deleting the raw counts dictionary of 27600 items
# 2019-11-09 22:30:00,359 : INFO : sample=0.001 downsamples 41 most-common words
# 2019-11-09 22:30:00,360 : INFO : downsampling leaves estimated 254493 word corpus (90.0% of prior 282671)
# 2019-11-09 22:30:00,385 : INFO : estimated required memory for 12387 words and 50 dimensions: 11148300 bytes
# 2019-11-09 22:30:00,386 : INFO : resetting layer weights
# 2019-11-09 22:30:02,331 : INFO : training model with 5 workers on 12387 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-09 22:30:02,685 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:02,692 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:02,707 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:02,710 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:02,716 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:02,716 : INFO : EPOCH - 1 : training on 297884 raw words (254551 effective words) took 0.4s, 681799 effective words/s
# 2019-11-09 22:30:03,089 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:03,091 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:03,095 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:03,096 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:03,108 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:03,109 : INFO : EPOCH - 2 : training on 297884 raw words (254550 effective words) took 0.4s, 668182 effective words/s
# 2019-11-09 22:30:03,455 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:03,456 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:03,475 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:03,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:03,477 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:03,479 : INFO : EPOCH - 3 : training on 297884 raw words (254378 effective words) took 0.4s, 702235 effective words/s
# 2019-11-09 22:30:03,821 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:03,837 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:03,838 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:03,848 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:03,856 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:03,857 : INFO : EPOCH - 4 : training on 297884 raw words (254545 effective words) took 0.4s, 694081 effective words/s
# 2019-11-09 22:30:04,213 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:04,221 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:04,225 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:04,229 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:04,230 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:04,232 : INFO : EPOCH - 5 : training on 297884 raw words (254315 effective words) took 0.4s, 698252 effective words/s
# 2019-11-09 22:30:04,233 : INFO : training on a 1489420 raw words (1272339 effective words) took 1.9s, 669500 effective words/s
# 2019-11-09 22:30:04,234 : WARNING : Effective 'alpha' higher than previous training cycles
# 2019-11-09 22:30:04,235 : INFO : training model with 5 workers on 12387 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-09 22:30:04,572 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:04,594 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:04,602 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:04,609 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:04,613 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:04,614 : INFO : EPOCH - 1 : training on 297884 raw words (254436 effective words) took 0.4s, 693205 effective words/s
# 2019-11-09 22:30:04,953 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:04,969 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:04,981 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:04,989 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:04,991 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:04,992 : INFO : EPOCH - 2 : training on 297884 raw words (254518 effective words) took 0.4s, 691359 effective words/s
# 2019-11-09 22:30:05,339 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:05,343 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:05,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:05,355 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:05,364 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:05,365 : INFO : EPOCH - 3 : training on 297884 raw words (254445 effective words) took 0.4s, 698590 effective words/s
# 2019-11-09 22:30:05,700 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:05,709 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:05,726 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:05,733 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:05,737 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:05,738 : INFO : EPOCH - 4 : training on 297884 raw words (254443 effective words) took 0.4s, 698561 effective words/s
# 2019-11-09 22:30:06,085 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:06,097 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:06,105 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:06,113 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:06,117 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:06,118 : INFO : EPOCH - 5 : training on 297884 raw words (254292 effective words) took 0.4s, 686947 effective words/s
# 2019-11-09 22:30:06,456 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:06,462 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:06,470 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:06,479 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:06,483 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:06,484 : INFO : EPOCH - 6 : training on 297884 raw words (254463 effective words) took 0.4s, 715674 effective words/s
# 2019-11-09 22:30:06,833 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:06,836 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:06,841 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:06,848 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:06,852 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:06,853 : INFO : EPOCH - 7 : training on 297884 raw words (254459 effective words) took 0.4s, 708438 effective words/s
# 2019-11-09 22:30:07,203 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:07,205 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:07,220 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:07,223 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:07,225 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:07,225 : INFO : EPOCH - 8 : training on 297884 raw words (254651 effective words) took 0.4s, 699605 effective words/s
# 2019-11-09 22:30:07,569 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:07,578 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:07,588 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:07,597 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:07,600 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:07,601 : INFO : EPOCH - 9 : training on 297884 raw words (254634 effective words) took 0.4s, 725386 effective words/s
# 2019-11-09 22:30:07,939 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-09 22:30:07,942 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-09 22:30:07,948 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-09 22:30:07,955 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-09 22:30:07,963 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-09 22:30:07,963 : INFO : EPOCH - 10 : training on 297884 raw words (254322 effective words) took 0.4s, 722235 effective words/s
# 2019-11-09 22:30:07,964 : INFO : training on a 2978840 raw words (2544663 effective words) took 3.7s, 682633 effective words/s
# CPU times: user 12.4 s, sys: 82.8 ms, total: 12.5 s
# Wall time: 7.75 s

# %%
# word_vectors = model.wv

# model.wv.save_word2vec_format('model.txt', binary=False)

# %%
# from gensim.test.utils import get_tmpfile
# from gensim.models import KeyedVectors

# fname = "hate_embeddings#1.kv"
# word_vectors.save(fname)
# word_vectors = KeyedVectors.load(fname, mmap='r')

# %%
w1 = "muslim"
model.wv.most_similar(positive=w1)
# Out:
# 2019-11-09 22:30:50,898 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('islam', 0.9447076320648193),
#  ('religion', 0.9309201240539551),
#  ('quran', 0.9206629395484924),
#  ('prophet', 0.9146885275840759),
#  ('jew', 0.9033626914024353),
#  ('mohammed', 0.8901999592781067),
#  ('pedophile', 0.883843183517456),
#  ('islamic', 0.8814033269882202),
#  ('terrorist', 0.8811196684837341),
#  ('propaganda', 0.878230094909668)]

# %%
model.wv.similarity(w1='queen',w2='royal')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.8024919

# %%
model.wv.similarity(w1='muslim',w2='islam')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.94470763

# %%
# [('muslim', 0.9584801197052002),
#  ('religion', 0.9454779028892517),
#  ('quran', 0.9349233508110046),
#  ('prophet', 0.9214071035385132),
#  ('declaration', 0.9209208488464355),
#  ('murder', 0.8991195559501648),
#  ('mohammed', 0.8898417353630066),
#  ('jew', 0.8868030309677124),
#  ('isi', 0.8843002915382385),
#  ('terrorist', 0.8834922909736633)]

# %%
model.wv.save_word2vec_format('tmp.txt', binary=False)
# omly domain based embeddings
# Out:
# 2019-11-09 22:30:58,360 : INFO : storing 12387x50 projection weights into tmp.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Transfer Learning

# %%
from gensim.models import Word2Vec
sentences = documents
# size option needs to be set to 300 to be the same as Google's pre-trained model
 
word2vec_model = Word2Vec(size = 300, window=5,
min_count = 1, workers = 10)

word2vec_model.build_vocab(sentences)
 
# assign the vectors to the vocabs that are in Google's pre-trained model and your sentences defined above.
# Out:
# 2019-10-25 22:19:27,996 : INFO : collecting all words and their counts
# 2019-10-25 22:19:27,997 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-10-25 22:19:28,029 : INFO : PROGRESS: at sentence #10000, processed 132532 words, keeping 11246 word types
# 2019-10-25 22:19:28,058 : INFO : PROGRESS: at sentence #20000, processed 262350 words, keeping 16950 word types
# 2019-10-25 22:19:28,087 : INFO : PROGRESS: at sentence #30000, processed 382207 words, keeping 22182 word types
# 2019-10-25 22:19:28,118 : INFO : PROGRESS: at sentence #40000, processed 512233 words, keeping 26850 word types
# 2019-10-25 22:19:28,127 : INFO : collected 27706 word types from a corpus of 541415 raw words and 42364 sentences
# 2019-10-25 22:19:28,128 : INFO : Loading a fresh vocabulary
# 2019-10-25 22:19:28,323 : INFO : effective_min_count=1 retains 27706 unique words (100% of original 27706, drops 0)
# 2019-10-25 22:19:28,324 : INFO : effective_min_count=1 leaves 541415 word corpus (100% of original 541415, drops 0)
# 2019-10-25 22:19:28,412 : INFO : deleting the raw counts dictionary of 27706 items
# 2019-10-25 22:19:28,413 : INFO : sample=0.001 downsamples 57 most-common words
# 2019-10-25 22:19:28,414 : INFO : downsampling leaves estimated 424048 word corpus (78.3% of prior 541415)
# 2019-10-25 22:19:28,474 : INFO : estimated required memory for 27706 words and 300 dimensions: 80347400 bytes
# 2019-10-25 22:19:28,476 : INFO : resetting layer weights

# %%
# lockf needs to be set to 1.0 to allow continued training.
word2vec_model.intersect_word2vec_format('/content/drive/My Drive/Hate_Speech_Detection_git/GoogleNews-vectors-negative300.bin.gz', lockf=1.0, binary=True)
# Out:
# 2019-10-25 22:19:34,849 : INFO : loading projection weights from /content/drive/My Drive/Hate_Speech_Detection_git/GoogleNews-vectors-negative300.bin.gz
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-10-25 22:21:21,998 : INFO : merged 17587 vectors into (27706, 300) matrix from /content/drive/My Drive/Hate_Speech_Detection_git/GoogleNews-vectors-negative300.bin.gz

# %%
# continue training with you own data
word2vec_model.train(sentences, total_examples=len(sentences), epochs = 5)
# Out:
# 2019-10-25 22:21:22,011 : INFO : training model with 10 workers on 27706 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-10-25 22:21:23,058 : INFO : EPOCH 1 - PROGRESS: at 81.13% examples, 335791 words/s, in_qsize 10, out_qsize 1
# 2019-10-25 22:21:23,060 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-25 22:21:23,086 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-25 22:21:23,111 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-25 22:21:23,113 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-25 22:21:23,117 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-25 22:21:23,146 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-25 22:21:23,148 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-25 22:21:23,151 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-25 22:21:23,159 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-25 22:21:23,167 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-25 22:21:23,167 : INFO : EPOCH - 1 : training on 541415 raw words (424220 effective words) took 1.1s, 372679 effective words/s
# 2019-10-25 22:21:24,186 : INFO : EPOCH 2 - PROGRESS: at 84.70% examples, 359511 words/s, in_qsize 9, out_qsize 1
# 2019-10-25 22:21:24,200 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-25 22:21:24,210 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-25 22:21:24,222 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-25 22:21:24,249 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-25 22:21:24,274 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-25 22:21:24,277 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-25 22:21:24,294 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-25 22:21:24,314 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-25 22:21:24,319 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-25 22:21:24,321 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-25 22:21:24,322 : INFO : EPOCH - 2 : training on 541415 raw words (424087 effective words) took 1.1s, 372079 effective words/s
# 2019-10-25 22:21:25,377 : INFO : EPOCH 3 - PROGRESS: at 81.09% examples, 331869 words/s, in_qsize 11, out_qsize 0
# 2019-10-25 22:21:25,401 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-25 22:21:25,404 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-25 22:21:25,412 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-25 22:21:25,438 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-25 22:21:25,449 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-25 22:21:25,450 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-25 22:21:25,453 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-25 22:21:25,457 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-25 22:21:25,459 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-25 22:21:25,474 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-25 22:21:25,475 : INFO : EPOCH - 3 : training on 541415 raw words (424110 effective words) took 1.1s, 372410 effective words/s
# 2019-10-25 22:21:26,547 : INFO : EPOCH 4 - PROGRESS: at 79.34% examples, 319196 words/s, in_qsize 9, out_qsize 4
# 2019-10-25 22:21:26,549 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-25 22:21:26,550 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-25 22:21:26,574 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-25 22:21:26,575 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-25 22:21:26,578 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-25 22:21:26,592 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-25 22:21:26,606 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-25 22:21:26,610 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-25 22:21:26,623 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-25 22:21:26,630 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-25 22:21:26,631 : INFO : EPOCH - 4 : training on 541415 raw words (424253 effective words) took 1.1s, 371258 effective words/s
# 2019-10-25 22:21:27,659 : INFO : EPOCH 5 - PROGRESS: at 83.27% examples, 349622 words/s, in_qsize 9, out_qsize 1
# 2019-10-25 22:21:27,664 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-25 22:21:27,701 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-25 22:21:27,716 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-25 22:21:27,723 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-25 22:21:27,744 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-25 22:21:27,755 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-25 22:21:27,769 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-25 22:21:27,771 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-25 22:21:27,782 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-25 22:21:27,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-25 22:21:27,785 : INFO : EPOCH - 5 : training on 541415 raw words (424354 effective words) took 1.1s, 371868 effective words/s
# 2019-10-25 22:21:27,790 : INFO : training on a 2707075 raw words (2121024 effective words) took 5.8s, 367166 effective words/s
# (2121024, 2707075)

# %%
w1 = ["bed"]
word2vec_model.wv.most_similar (positive=w1)
# Out:
# 2019-10-25 22:25:42,183 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('middleearth', 0.6938994526863098),
#  ('room', 0.6501486301422119),
#  ('kitchen', 0.6442478895187378),
#  ('sleep', 0.6377359628677368),
#  ('sleeping', 0.6332756280899048),
#  ('couch', 0.629835844039917),
#  ('topqbs', 0.6250707507133484),
#  ('mouthlol', 0.6173553466796875),
#  ('darg', 0.6171203851699829),
#  ('catchmeifyoucanim', 0.6152539849281311)]

# %%
w1 = ["islam"]
word2vec_model.wv.most_similar (positive=w1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('muslim', 0.8201450705528259),
#  ('religion', 0.8187536597251892),
#  ('isi', 0.7753992080688477),
#  ('islamic', 0.7538473010063171),
#  ('quran', 0.7297672033309937),
#  ('microbrain', 0.7268235087394714),
#  ('christian', 0.721429705619812),
#  ('mohammed', 0.7090685367584229),
#  ('christianity', 0.6701181530952454),
#  ('israel', 0.6650323867797852)]

# %%
word2vec_model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.6034551

# %%
# word2vec_model.wv.save_word2vec_format('model_transfer_learning.txt', binary=False)
word2vec_model.wv.save_word2vec_format('model_transfer_learning_including_stopwords.txt', binary=False)
# Out:
# 2019-10-25 22:26:05,451 : INFO : storing 27706x300 projection weights into model_transfer_learning_including_stopwords.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Training on new word2vec model

# %%
import gensim
import logging
from gensim.models import Word2Vec
# wv = gensim.models.KeyedVectors.load_word2vec_format("/content/drive/My Drive/Hate_Speech_Detection_git/GoogleNews-vectors-negative300.bin.gz", binary=True)

# wv = gensim.models.KeyedVectors.load_word2vec_format("/content/drive/My Drive/Hate_Speech_Detection_git/model_transfer_learning.txt", binary=False)

# wv = gensim.models.KeyedVectors.load_word2vec_format("/content/drive/My Drive/Hate_Speech_Detection_git/model_transfer_learning_including_stopwords.txt", binary=False)

wv = gensim.models.KeyedVectors.load_word2vec_format("tmp.txt", binary=False) ## only domain based embeddings

wv.init_sims(replace=True)
# Out:
# 2019-11-09 22:31:20,332 : INFO : loading projection weights from tmp.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-11-09 22:31:20,897 : INFO : loaded (12387, 50) matrix from tmp.txt
# 2019-11-09 22:31:20,902 : INFO : precomputing L2-norms of word weight vectors

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.syn0norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(wv.vector_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, post) for post in text_list ])

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='english'):
        for word in nltk.word_tokenize(sent, language='english'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens
    
train_w2v, test_w2v = train_test_split(train, test_size=0.2, random_state = 42)
# x_t,x_v,y_t,y_v = train_test_split(train['tweet'],train['class'],test_size=0.2,random_state=234)

test_tokenized = test_w2v.apply(lambda r: w2v_tokenize_text(r['tweet']), axis=1).values
train_tokenized = train_w2v.apply(lambda r: w2v_tokenize_text(r['tweet']), axis=1).values

X_train_word_average = word_averaging_list(wv,train_tokenized)
X_test_word_average = word_averaging_list(wv,test_tokenized)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
#
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 2019-11-09 22:31:56,582 : WARNING : cannot compute similarity with no input ['projectdrugsampbitches']
# 2019-11-09 22:31:56,598 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,616 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,620 : WARNING : cannot compute similarity with no input ['scanger']
# 2019-11-09 22:31:56,627 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,631 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,638 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,647 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,659 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,676 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,687 : WARNING : cannot compute similarity with no input ['voilá', 'walla']
# 2019-11-09 22:31:56,693 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,700 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,706 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,711 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,714 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,717 : WARNING : cannot compute similarity with no input ['bucookie']
# 2019-11-09 22:31:56,725 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,728 : WARNING : cannot compute similarity with no input ['mkrnz', 'aotearoa', 'pasifika', 'ttou']
# 2019-11-09 22:31:56,734 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,759 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,760 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,762 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,765 : WARNING : cannot compute similarity with no input ['pedos']
# 2019-11-09 22:31:56,774 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,780 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,787 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,793 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,799 : WARNING : cannot compute similarity with no input ['hiho']
# 2019-11-09 22:31:56,801 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,810 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,821 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,825 : WARNING : cannot compute similarity with no input ['ubitchu']
# 2019-11-09 22:31:56,840 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,853 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,859 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,867 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,869 : WARNING : cannot compute similarity with no input ['yawning']
# 2019-11-09 22:31:56,871 : WARNING : cannot compute similarity with no input ['comedinewithme']
# 2019-11-09 22:31:56,877 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,882 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,891 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,897 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,901 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,904 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,909 : WARNING : cannot compute similarity with no input ['nigor']
# 2019-11-09 22:31:56,913 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,918 : WARNING : cannot compute similarity with no input ['stopbeingsexist']
# 2019-11-09 22:31:56,932 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,944 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,950 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,958 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,963 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,971 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:56,986 : WARNING : cannot compute similarity with no input ['nooooooooooooooooo']
# 2019-11-09 22:31:56,996 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,008 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,014 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,029 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,045 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,047 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,056 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,063 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,069 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,073 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,077 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,086 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,091 : WARNING : cannot compute similarity with no input ['corsair', 'rgb']
# 2019-11-09 22:31:57,104 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,114 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,115 : WARNING : cannot compute similarity with no input ['php']
# 2019-11-09 22:31:57,137 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,140 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,146 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,150 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,160 : WARNING : cannot compute similarity with no input ['coinckydink']
# 2019-11-09 22:31:57,169 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,177 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,185 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,207 : WARNING : cannot compute similarity with no input ['ditto']
# 2019-11-09 22:31:57,216 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,222 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,225 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,229 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,238 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,240 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,246 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,255 : WARNING : cannot compute similarity with no input ['daaaaaaaad']
# 2019-11-09 22:31:57,274 : WARNING : cannot compute similarity with no input ['asphyxiate', 'disengage', 'whaaaaat']
# 2019-11-09 22:31:57,278 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,280 : WARNING : cannot compute similarity with no input ['juicebro']
# 2019-11-09 22:31:57,293 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,300 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,300 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,303 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,305 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,328 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,333 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,334 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,341 : WARNING : cannot compute similarity with no input ['squeeeee']
# 2019-11-09 22:31:57,343 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,345 : WARNING : cannot compute similarity with no input ['booooo']
# 2019-11-09 22:31:57,351 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,353 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,362 : WARNING : cannot compute similarity with no input ['poptarts', 'stuffoflegends']
# 2019-11-09 22:31:57,374 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,383 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,391 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,393 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,401 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,408 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,431 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,439 : WARNING : cannot compute similarity with no input ['nooooooooooooo']
# 2019-11-09 22:31:57,441 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,457 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,466 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,471 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,477 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,483 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,493 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,499 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,505 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,507 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,513 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,520 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,522 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,523 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,525 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,530 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,532 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,541 : WARNING : cannot compute similarity with no input ['countrycousins']
# 2019-11-09 22:31:57,545 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,554 : WARNING : cannot compute similarity with no input ['foooood']
# 2019-11-09 22:31:57,565 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,567 : WARNING : cannot compute similarity with no input ['backawayfromthetable', 'theenvygap', 'blackfeminists']
# 2019-11-09 22:31:57,585 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,589 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,592 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,604 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,614 : WARNING : cannot compute similarity with no input ['breakingfreefromfeministidiots']
# 2019-11-09 22:31:57,619 : WARNING : cannot compute similarity with no input ['summoned', 'soc']
# 2019-11-09 22:31:57,633 : WARNING : cannot compute similarity with no input ['boonch']
# 2019-11-09 22:31:57,637 : WARNING : cannot compute similarity with no input ['siiiiiiigh']
# 2019-11-09 22:31:57,645 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,650 : WARNING : cannot compute similarity with no input ['siiiiiiiiiiiiiiiiiiiiiiiigh']
# 2019-11-09 22:31:57,662 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,669 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,672 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,681 : WARNING : cannot compute similarity with no input ['mislabeled']
# 2019-11-09 22:31:57,689 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,717 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,740 : WARNING : cannot compute similarity with no input ['shingy']
# 2019-11-09 22:31:57,743 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,746 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,751 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,765 : WARNING : cannot compute similarity with no input ['hahahahhahaha']
# 2019-11-09 22:31:57,769 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,778 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,784 : WARNING : cannot compute similarity with no input ['gozlemetastic']
# 2019-11-09 22:31:57,797 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,801 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,806 : WARNING : cannot compute similarity with no input ['siiiiigh']
# 2019-11-09 22:31:57,810 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,817 : WARNING : cannot compute similarity with no input ['falseequivalence']
# 2019-11-09 22:31:57,823 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,832 : WARNING : cannot compute similarity with no input ['rtreplyblock', 'soothing']
# 2019-11-09 22:31:57,840 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,844 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,850 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,852 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,854 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,873 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,879 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,897 : WARNING : cannot compute similarity with no input ['jirabitbucket']
# 2019-11-09 22:31:57,914 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,924 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,945 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,957 : WARNING : cannot compute similarity with no input ['katmkr']
# 2019-11-09 22:31:57,963 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,978 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,984 : WARNING : cannot compute similarity with no input ['argie']
# 2019-11-09 22:31:57,987 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:57,997 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,007 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,024 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,026 : WARNING : cannot compute similarity with no input ['niger']
# 2019-11-09 22:31:58,029 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,048 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,060 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,068 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,073 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,100 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,121 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,125 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,141 : WARNING : cannot compute similarity with no input ['newp']
# 2019-11-09 22:31:58,149 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,151 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,152 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,153 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,167 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,173 : WARNING : cannot compute similarity with no input ['tweetthatshit']
# 2019-11-09 22:31:58,176 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,180 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,183 : WARNING : cannot compute similarity with no input ['thanksbitch']
# 2019-11-09 22:31:58,199 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,205 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,223 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,237 : WARNING : cannot compute similarity with no input ['nidge']
# 2019-11-09 22:31:58,244 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,260 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,271 : WARNING : cannot compute similarity with no input ['siiiigh']
# 2019-11-09 22:31:58,275 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,278 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,289 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,300 : WARNING : cannot compute similarity with no input ['vipperloid', 'bitchp']
# 2019-11-09 22:31:58,307 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,312 : WARNING : cannot compute similarity with no input ['yeahbitch']
# 2019-11-09 22:31:58,316 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,319 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,321 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,333 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,345 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,351 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,356 : WARNING : cannot compute similarity with no input ['nay']
# 2019-11-09 22:31:58,366 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,368 : WARNING : cannot compute similarity with no input ['disappointwadhwa']
# 2019-11-09 22:31:58,378 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,383 : WARNING : cannot compute similarity with no input ['mightcould']
# 2019-11-09 22:31:58,389 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,398 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,408 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,417 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,425 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,439 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,448 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,453 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,457 : WARNING : cannot compute similarity with no input ['teamsteve']
# 2019-11-09 22:31:58,464 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,466 : WARNING : cannot compute similarity with no input ['snooor']
# 2019-11-09 22:31:58,470 : WARNING : cannot compute similarity with no input ['ghettoblack']
# 2019-11-09 22:31:58,477 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,493 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,500 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,512 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,524 : WARNING : cannot compute similarity with no input ['_ツ_']
# 2019-11-09 22:31:58,533 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,540 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,544 : WARNING : cannot compute similarity with no input ['spatchcocky']
# 2019-11-09 22:31:58,549 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,562 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,570 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,574 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,584 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,597 : WARNING : cannot compute similarity with no input ['weetbix']
# 2019-11-09 22:31:58,608 : WARNING : cannot compute similarity with no input ['katisawanker']
# 2019-11-09 22:31:58,613 : WARNING : cannot compute similarity with no input ['islamicstatemedia']
# 2019-11-09 22:31:58,617 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,624 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,629 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,643 : WARNING : cannot compute similarity with no input ['whatajoke', 'makeitadoubleelimination']
# 2019-11-09 22:31:58,650 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,652 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,666 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,673 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,678 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,685 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,689 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,703 : WARNING : cannot compute similarity with no input ['feminazixd']
# 2019-11-09 22:31:58,708 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,712 : WARNING : cannot compute similarity with no input ['magnificent']
# 2019-11-09 22:31:58,714 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,718 : WARNING : cannot compute similarity with no input ['draaaaaaaaaaaaaaaaaaaaging']
# 2019-11-09 22:31:58,731 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,732 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,734 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,755 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,773 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,777 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,778 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,788 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,798 : WARNING : cannot compute similarity with no input ['lmgtfy']
# 2019-11-09 22:31:58,806 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,824 : WARNING : cannot compute similarity with no input ['deadme']
# 2019-11-09 22:31:58,826 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,839 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,841 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,842 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,847 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,848 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,856 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,869 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,876 : WARNING : cannot compute similarity with no input ['matcha']
# 2019-11-09 22:31:58,885 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,888 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,892 : WARNING : cannot compute similarity with no input ['feministfailedfeminazibigred']
# 2019-11-09 22:31:58,899 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,904 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,919 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,922 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,927 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,946 : WARNING : cannot compute similarity with no input ['notyourshield']
# 2019-11-09 22:31:58,948 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,960 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,972 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,973 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:58,975 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,029 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,030 : WARNING : cannot compute similarity with no input ['lorax', 'doorbell']
# 2019-11-09 22:31:59,035 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,040 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,045 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,048 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,054 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,061 : WARNING : cannot compute similarity with no input ['slapahoe']
# 2019-11-09 22:31:59,067 : WARNING : cannot compute similarity with no input ['modtalkleak']
# 2019-11-09 22:31:59,068 : WARNING : cannot compute similarity with no input ['wexican']
# 2019-11-09 22:31:59,070 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,081 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,092 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,099 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,106 : WARNING : cannot compute similarity with no input ['rtfm']
# 2019-11-09 22:31:59,109 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,119 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,129 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,139 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,148 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,154 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,162 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,166 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,171 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,177 : WARNING : cannot compute similarity with no input ['buckwheat', 'porky']
# 2019-11-09 22:31:59,190 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,194 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,196 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,197 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,202 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,210 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,215 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,221 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,222 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,227 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,239 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,241 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,254 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,268 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,276 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,278 : WARNING : cannot compute similarity with no input ['hoooooolllllleeeeyyyyyy', 'sssshhhhhiiiitttttttttt']
# 2019-11-09 22:31:59,283 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,291 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,291 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,303 : WARNING : cannot compute similarity with no input ['teamrobertandlynzey']
# 2019-11-09 22:31:59,305 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,327 : WARNING : cannot compute similarity with no input ['katandandrearejustmeanespeciallykat', 'notnicepeople', 'gonsw']
# 2019-11-09 22:31:59,330 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,337 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,343 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,344 : WARNING : cannot compute similarity with no input ['certainlt', 'paddy']
# 2019-11-09 22:31:59,356 : WARNING : cannot compute similarity with no input ['youre_welcome_exe']
# 2019-11-09 22:31:59,369 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,377 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,383 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,391 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,396 : WARNING : cannot compute similarity with no input ['unsubscribe']
# 2019-11-09 22:31:59,404 : WARNING : cannot compute similarity with no input ['summarizestatscounterstweetstatshashtagallcountmsum']
# 2019-11-09 22:31:59,410 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,411 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,418 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,419 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,422 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,434 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,438 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,441 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,452 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,468 : WARNING : cannot compute similarity with no input ['mrn']
# 2019-11-09 22:31:59,473 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,478 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,485 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,486 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,497 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,502 : WARNING : cannot compute similarity with no input ['nooooooooooooooo']
# 2019-11-09 22:31:59,507 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,525 : WARNING : cannot compute similarity with no input ['euuuuuuurggggh']
# 2019-11-09 22:31:59,529 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,533 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,539 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,542 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,565 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,567 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,577 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,582 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,596 : WARNING : cannot compute similarity with no input ['bantheburka']
# 2019-11-09 22:31:59,597 : WARNING : cannot compute similarity with no input []
# 2019-11-09 22:31:59,603 : WARNING : cannot compute similarity with no input []

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklfrom sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, classification_report, roc_auc_score, confusion_matrix, accuracy_scoreearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, classification_report, roc_auc_score, confusion_matrix, accuracy_score

# %%
xgb_w2v = XGBClassifier(n_estimators=500, max_depth=5,learning_rate=0.1,scale_pos_weight=1.4266790777602751)
lgr_w2v = LogisticRegression(n_jobs=1)
model_training(xgb_w2v,X_train_word_average,train_w2v['class'],X_test_word_average,test_w2v['class'])
# model_training(lgr_w2v,X_train_word_average,train_w2v['class'],X_test_word_average,test_w2v['class'])
# Out:
# training accuracy 0.9647512973041387
# validation accuracy 0.8591495823842066
# validation f1_score 0.8885774351786966
# validation roc_auc score 0.9350368582573201
# confusion matrix
#  [[2351  581]
#  [ 532 4438]]
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1.4266790777602751,
#               seed=None, silent=None, subsample=1, verbosity=1)

# %%
print('validation accuracy', xgb_w2v.score(X_test_word_average,test_w2v['class']))
print('validation f1_score',f1_score(xgb_w2v.predict(X_test_word_average),test_w2v['class']))
# Out:
# validation accuracy 0.8437539313121147
# validation f1_score 0.8771027112606371

# %%
# Logistic Regression + Only domain embeddings
# training accuracy 0.8346095430958107
# validation accuracy 0.837129840546697
# validation f1_score 0.8693533651405949
# validation roc_auc score 0.9120879437607912
# confusion matrix 
#  [[2333  599]
#  [ 688 4282]]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=1, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)


# XGBoost + Only Domain Based Embeddings
# training accuracy 0.9647512973041387
# validation accuracy 0.8591495823842066
# validation f1_score 0.8885774351786966
# validation roc_auc score 0.9350368582573201
# confusion matrix 
#  [[2351  581]
#  [ 532 4438]]
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1.4266790777602751,
#               seed=None, silent=None, subsample=1, verbosity=1)

# %%
confusion_matrix(test_w2v['class'],xgb_w2v.predict(X_test_word_average))
# Out:
# array([[3005,  495],
#        [ 574, 4399]])

# %%
# array([[3025,  475],
#        [ 540, 4433]])

# %%
# logreg = LogisticRegression(n_jobs=1, C=1e5)
# logreg = logreg.fit(X_train_word_average, train_w2v['class'])
# y_pred = logreg.predict(X_test_word_average)

# print('accuracy %s' % accuracy_score(y_pred, test_w2v['class']))
# print(classification_report(test_w2v['class'], y_pred))
# print(confusion_matrix(test_w2v['class'],y_pred))

# %%
f1_score(test_w2v['class'],y_pred)
# 0.8864864864864865

# %%
y = test_w2v['class']

# %%
probabs_df = pd.DataFrame(y)
probabs_df['original_index'] = y.index
probabs_df['probab'] = logreg.predict_proba(X_test_word_average)[::,-1]

probabs_df = probabs_df.sort_values(by = 'probab',ascending=False).reset_index(drop=True)

probabs_df.loc[0:int(X_test_word_average.shape[0]*y.mean()),'preds'] = 1

probabs_df.loc[int(X_test_word_average.shape[0]*y.mean()):,'preds'] = 0

np.mean(probabs_df['class']==probabs_df['preds'])
# Out:
# 0.8661631063377788

# %%
f1_score(probabs_df['class'],probabs_df['preds'])
# Out:
# 0.8859843153026342

# %%
confusion_matrix(probabs_df['class'],probabs_df['preds'])
# Out:
# array([[2933,  567],
#        [ 567, 4406]])

# %%
### its increasing the True positives which is good!! Although we are getting a bit more false alarms
### that is the false positives, but the false negatives are decreased and thats what we need
